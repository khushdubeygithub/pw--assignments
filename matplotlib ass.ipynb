# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.
#
# Matplotlib is a popular Python library for creating static, animated, and interactive visualizations in a wide range of formats. It provides a powerful and flexible framework for generating various types of plots and charts. Matplotlib is used for data visualization, allowing users to present data in a graphical format to make it easier to understand and interpret. Some common plots that can be created using the Pyplot module of Matplotlib include:
#
# Line plots
# Scatter plots
# Bar plots
# Histograms
# Box plots

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data, plot a scatter plot.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

plt.scatter(x, y)
plt.title('Scatter Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
#
# The subplot() function in Matplotlib is used to create multiple subplots or axes within a single figure. It allows you to arrange and display multiple plots in a grid-like fashion, making it easier to compare and visualize different datasets or aspects of your data simultaneously.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([0, 1, 2, 3, 4, 5])

# Line 1
y1 = np.array([0, 100, 200, 300, 400, 500])
plt.subplot(2, 2, 1)
plt.plot(x, y1)
plt.title('Line Plot 1')

# Line 2
y2 = np.array([50, 20, 40, 20, 60, 70])
plt.subplot(2, 2, 2)
plt.plot(x, y2)
plt.title('Line Plot 2')

# Line 3
y3 = np.array([10, 20, 30, 40, 50, 60])
plt.subplot(2, 2, 3)
plt.plot(x, y3)
plt.title('Line Plot 3')

# Line 4
y4 = np.array([200, 350, 250, 550, 450, 150])
plt.subplot(2, 2, 4)
plt.plot(x, y4)
plt.title('Line Plot 4')

plt.tight_layout()
plt.show()

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data, plot a bar plot and a horizontal bar plot.
#
# A bar plot (or bar chart) is a graphical representation of categorical data with rectangular bars. It is used to compare the values of different categories and is particularly effective for displaying discrete data. Bar plots are used to visualize and compare data across different categories or groups.

# %%
import numpy as np
import matplotlib.pyplot as plt

company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# Vertical Bar Plot
plt.figure(figsize=(8, 4))
plt.bar(company, profit)
plt.title('Vertical Bar Plot')
plt.xlabel('Company')
plt.ylabel('Profit (in billions)')
plt.show()

# Horizontal Bar Plot
plt.figure(figsize=(8, 4))
plt.barh(company, profit)
plt.title('Horizontal Bar Plot')
plt.xlabel('Profit (in billions)')
plt.ylabel('Company')
plt.show()

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data, plot a box plot.
#
# A box plot (or box-and-whisker plot) is a graphical representation of the distribution of a dataset. It displays summary statistics such as the median, quartiles, and potential outliers. Box plots are used to visualize the spread and skewness of data, making it easier to identify the central tendency and variability within a dataset.

# %%
import numpy as np
import matplotlib.pyplot as plt

box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

data = [box1, box2]

plt.boxplot(data, labels=['Box 1', 'Box 2'])
plt.title('Box Plot')
plt.ylabel('Values')
plt.show()
